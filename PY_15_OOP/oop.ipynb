# %%
class Client:
    # Базовые данные
    def __init__(self, email, order_num, registration_year):
        self.email = email
        self.order_num = order_num
        self.registration_year = registration_year
        self.discount = 0

    # Оформление заказа
    def make_order(self, price):
        self.update_discount()
        self.order_num += 1
        # Здесь было бы оформление заказа, но мы просто выведем его цену
        discounted_price = price * (1 - self.discount)
        print(f"Order price for {self.email} is {discounted_price}")

    # Назначение скидки
    def update_discount(self):
        if self.registration_year < 2018 and self.order_num >= 5:
            self.discount = 0.1


# Применение

# Сделаем подобие базы
client_db = [
    Client("max@gmail.com", 2, 2019),
    Client("lova@yandex.ru", 10, 2015),
    Client("german@sberbank.ru", 4, 2017)
]


# Сгенерируем заказы
client_db[0].make_order(100)
# => Order price for max@gmail.com is 100

client_db[1].make_order(200)
# => Order price for lova@yandex.ru is 180.0

client_db[2].make_order(500)
# => Order price for german@sberbank.ru is 500

client_db[2].make_order(500)
# => Order price for german@sberbank.ru is 450.0
# Out:
# Order price for max@gmail.com is 100
# Order price for lova@yandex.ru is 180.0
# Order price for german@sberbank.ru is 500
# Order price for german@sberbank.ru is 450.0

# %%
class User:
    def __init__(self, email, password, balance):
        self.email = email
        self.password = password
        self.balance = balance

    def login(self, email, password):
        if self.email == email and self.password == password:
            return True
        return False

    def update_balance(self, amount):
        self.balance = self.balance + amount



user = User("gosha@roskino.org", "qwerty", 20_000)
print(user.login("gosha@roskino.org", "qwerty123"))
# False
print(user.login("gosha@roskino.org", "qwerty"))
# True
user.update_balance(200)
user.update_balance(-500)
print(user.balance)
# 19700
# Out:
# False
# True
# 19700

# %%
import statistics

class DataFrame:
    def __init__(self, column, fill_value=0):
        # Инициализируем атрибуты
        self.column = column
        self.fill_value = fill_value
        # Заполним пропуски
        self.fill_missed()
        # Конвертируем все элементы в числа
        self.to_float()

    def fill_missed(self):
        for i, value in enumerate(self.column):
            if value is None or value == '':
                self.column[i] = self.fill_value

    def to_float(self):
        self.column = [float(value) for value in self.column]

    def median(self):
        return statistics.median(self.column)

    def mean(self):
        return statistics.mean(self.column)

    def deviation(self):
        return statistics.stdev(self.column)



# Воспользуемся классом
df = DataFrame(["1", 17, 4, None, 8])

print(df.column)
# => [1.0, 17.0, 4.0, 0.0, 8.0]
print(df.deviation())
# => 6.89
print(df.median())
# => 4.0
# Out:
# [1.0, 17.0, 4.0, 0.0, 8.0]
# 6.892024376045111
# 4.0

# %%
class IntDataFrame:
    def __init__(self, column):
        self.column = column
        self.to_int()

    def to_int(self):
        self.column = [int(value) for value in self.column]

    def count(self):
        count = 0
        for num in self.column:
            if num != 0:
                count += 1
        return count

    def unique(self):
        return len(set(self.column))


df = IntDataFrame([4.7, 4, 3, 0, 2.4, 0.3, 4])

print(df.column)
# [4, 4, 3, 0, 2, 0, 4]

print(df.count())
# 5

print(df.unique())
# 4
# Out:
# [4, 4, 3, 0, 2, 0, 4]
# 5
# 4

# %%
import pickle
from datetime import datetime
from os import path

class Dumper:
    def __init__(self, archive_dir="archive/"):
        self.archive_dir = archive_dir

    def dump(self, data):
        # Библиотека pickle позволяет доставать и класть объекты в файл
        with open(self.get_file_name(), 'wb') as file:
            pickle.dump(data, file)

    def load_for_day(self, day):
        file_name = path.join(self.archive_dir, day + ".pkl")
        with open(file_name, 'rb') as file:
            sets = pickle.load(file)
        return sets

    # возвращает корректное имя для файла
    def get_file_name(self):
        today = datetime.now().strftime("%y-%m-%d")
        return path.join(self.archive_dir, today + ".pkl")


# Пример использования

data = {
    'perfomance': [10, 20, 10],
    'clients': {"Romashka": 10, "Vector": 34}
}


dumper = Dumper()

# Сохраним данные
dumper.dump(data)

# Восстановим для сегодняшней даты
file_name = datetime.now().strftime("%y-%m-%d")
restored_data = dumper.load_for_day(file_name)
print(restored_data)
# => {'perfomance': [10, 20, 10], 'clients': {'Romashka': 10, 'Vector': 34}}
# Out:
# {'perfomance': [10, 20, 10], 'clients': {'Romashka': 10, 'Vector': 34}}

# %%
class OwnLogger:
    def __init__(self):
        self.logs = {"info": None, "warning": None, "error": None, "all": None}


    def log(message, level):





logger = OwnLogger()
logger.log("System started", "info")
logger.show_last("error")
# None
# Некоторые интерпретаторы Python могут не выводить None, тогда в этой проверке у вас будет пустая строка
logger.log("Connection instable", "warning")
logger.log("Connection lost", "error")

logger.show_last()
# Connection lost
logger.show_last("info")
# System started

# %%
class OwnLogger:
    def __init__(self):
        self.logs = {"info": None, "warning": None, "error": None, "all": None}

    def log(self, message, level):
        self.logs[level] = message
        self.logs["all"] = message

    def show_last(self, level="all"):
        return self.logs.get(level, None)


logger = OwnLogger()
logger.log("System started", "info")
print(logger.show_last("error"))  # None
logger.log("Connection instable", "warning")
logger.log("Connection lost", "error")

print(logger.show_last())  # Connection lost
print(logger.show_last("info"))  # System started
# Out:
# None
# Connection lost
# System started

# %%
from helpers.dumper import Dumper
from helpers.data_frame import DataFrame
from helpers.client import Client

# %%
class Dog:
    def bark(self, *args):
        return "Bark!"

    def give_paw(self, *args):
        return "Paw"

# %%
import os
# получить текущий путь
start_path = os.getcwd()
print(start_path)
# Out:
# /Users/gregnaumkin/PycharmProjects/python-practice/PY_15_OOP

# %%
os.chdir("..")
current_path = os.getcwd()
print(current_path)
# Out:
# /Users/gregnaumkin/PycharmProjects

# %%
print(os.listdir())

if 'tmp.py' not in os.listdir():
    print("Файл отсутствует в данной директории")
# Out:
# ['python-practice', '.DS_Store', 'sf-home-work-project', 'practice']
# Файл отсутствует в данной директории

# %%
print(start_path)
print(os.path.join(start_path, 'test'))
# Out:
# /Users/gregnaumkin/PycharmProjects/python-practice/PY_15_OOP
# /Users/gregnaumkin/PycharmProjects/python-practice/PY_15_OOP/test

# %%
# Сделайте функцию, которая принимает от пользователя путь и выводит всю информацию о содержимом этой папки.
# Для реализации используйте функцию встроенного модуля os.walk(). Если путь не указан, то сравнение начинается с текущей директории.
def walk_desc(path=None):
    start_path = path if path is not None else os.getcwd()

    for root, dirs, files in os.walk(start_path):
        print("Текущая директория", root)
        print("---")

        if dirs:
            print("Список папок", dirs)
        else:
            print("Папок нет")
        print("---")

        if files:
            print("Список файлов", files)
        else:
            print("Файлов нет")
        print("---")

        if files and dirs:
            print("Все пути:")
        for f in files:
            print("Файл ", os.path.join(root, f))
        for d in dirs:
            print("Папка ", os.path.join(root, d))
        print("===")

walk_desc()
# Out:
# Текущая директория /Users/gregnaumkin/PycharmProjects
# ---
# Список папок ['python-practice', 'sf-home-work-project', 'practice']
# ---
# Список файлов ['.DS_Store']
# ---
# Все пути:
# Файл  /Users/gregnaumkin/PycharmProjects/.DS_Store
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project
# Папка  /Users/gregnaumkin/PycharmProjects/practice
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice
# ---
# Список папок ['PY_11_pandas_base', 'numpy_learning', 'PY_15_OOP', 'PY_12_pandas_advaneced', 'PY_10_pandas_intro', 'PY_14_data_cleaning', '.git', 'PY_13_visualisation', '.idea']
# ---
# Список файлов ['.DS_Store', 'README.md', '.gitignore']
# ---
# Все пути:
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.DS_Store
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/README.md
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.gitignore
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/PY_11_pandas_base
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/numpy_learning
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/PY_15_OOP
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/PY_12_pandas_advaneced
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/PY_10_pandas_intro
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/PY_14_data_cleaning
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/PY_13_visualisation
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.idea
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/PY_11_pandas_base
# ---
# Список папок ['data']
# ---
# Список файлов ['pandas_base_practice.py', 'pandas_base.py']
# ---
# Все пути:
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_11_pandas_base/pandas_base_practice.py
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_11_pandas_base/pandas_base.py
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/PY_11_pandas_base/data
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/PY_11_pandas_base/data
# ---
# Папок нет
# ---
# Список файлов ['ufo.csv', 'citibike-tripdata.csv', 'melb_data_ps.csv']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_11_pandas_base/data/ufo.csv
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_11_pandas_base/data/citibike-tripdata.csv
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_11_pandas_base/data/melb_data_ps.csv
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/numpy_learning
# ---
# Папок нет
# ---
# Список файлов ['numpy_practice.py']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/numpy_learning/numpy_practice.py
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/PY_15_OOP
# ---
# Список папок ['archive', 'helpers']
# ---
# Список файлов ['oop.ipynb']
# ---
# Все пути:
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_15_OOP/oop.ipynb
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/PY_15_OOP/archive
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/PY_15_OOP/helpers
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/PY_15_OOP/archive
# ---
# Папок нет
# ---
# Список файлов ['25-03-01.pkl']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_15_OOP/archive/25-03-01.pkl
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/PY_15_OOP/helpers
# ---
# Папок нет
# ---
# Список файлов ['client.py', '__init__.py', 'dumper.py', 'data_frame.py']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_15_OOP/helpers/client.py
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_15_OOP/helpers/__init__.py
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_15_OOP/helpers/dumper.py
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_15_OOP/helpers/data_frame.py
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/PY_12_pandas_advaneced
# ---
# Список папок ['data']
# ---
# Список файлов ['pandas_advanced_movies.py', 'pandas_advanced.py']
# ---
# Все пути:
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_12_pandas_advaneced/pandas_advanced_movies.py
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_12_pandas_advaneced/pandas_advanced.py
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/PY_12_pandas_advaneced/data
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/PY_12_pandas_advaneced/data
# ---
# Список папок ['movies_data']
# ---
# Список файлов ['melb_data_fe.csv', 'products.csv', 'orders.csv']
# ---
# Все пути:
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_12_pandas_advaneced/data/melb_data_fe.csv
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_12_pandas_advaneced/data/products.csv
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_12_pandas_advaneced/data/orders.csv
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/PY_12_pandas_advaneced/data/movies_data
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/PY_12_pandas_advaneced/data/movies_data
# ---
# Папок нет
# ---
# Список файлов ['ratings_movies.csv', 'ratings1.csv', 'ratings2.csv', 'dates.csv', 'movies.csv']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_12_pandas_advaneced/data/movies_data/ratings_movies.csv
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_12_pandas_advaneced/data/movies_data/ratings1.csv
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_12_pandas_advaneced/data/movies_data/ratings2.csv
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_12_pandas_advaneced/data/movies_data/dates.csv
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_12_pandas_advaneced/data/movies_data/movies.csv
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/PY_10_pandas_intro
# ---
# Список папок ['__pycache__', 'data']
# ---
# Список файлов ['.DS_Store', 'pandas_intro.py']
# ---
# Все пути:
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_10_pandas_intro/.DS_Store
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_10_pandas_intro/pandas_intro.py
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/PY_10_pandas_intro/__pycache__
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/PY_10_pandas_intro/data
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/PY_10_pandas_intro/__pycache__
# ---
# Папок нет
# ---
# Список файлов ['pandas_intro.cpython-311.pyc']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_10_pandas_intro/__pycache__/pandas_intro.cpython-311.pyc
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/PY_10_pandas_intro/data
# ---
# Папок нет
# ---
# Список файлов ['countries.csv', 'melb_data.csv', 'students_performance.csv']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_10_pandas_intro/data/countries.csv
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_10_pandas_intro/data/melb_data.csv
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_10_pandas_intro/data/students_performance.csv
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/PY_14_data_cleaning
# ---
# Список папок ['data']
# ---
# Список файлов ['data_cleaning.ipynb', 'data_cleaning_practice.ipynb']
# ---
# Все пути:
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_14_data_cleaning/data_cleaning.ipynb
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_14_data_cleaning/data_cleaning_practice.ipynb
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/PY_14_data_cleaning/data
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/PY_14_data_cleaning/data
# ---
# Папок нет
# ---
# Список файлов ['diabetes_data.csv', 'sber_data.csv']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_14_data_cleaning/data/diabetes_data.csv
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_14_data_cleaning/data/sber_data.csv
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git
# ---
# Список папок ['objects', 'info', 'logs', 'hooks', 'refs']
# ---
# Список файлов ['config', 'HEAD', 'description', 'index', 'packed-refs', 'COMMIT_EDITMSG']
# ---
# Все пути:
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/config
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/HEAD
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/description
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/index
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/packed-refs
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/COMMIT_EDITMSG
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/info
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/logs
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/hooks
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/refs
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects
# ---
# Список папок ['50', '03', '0e', 'd1', 'd8', 'f3', 'fb', 'pack', '1a', '10', '75', '9f', '6b', 'info', '54', '97', 'd4', 'c3', 'cc', 'e6', 'e8', 'ff', 'cb', '77', '4f', '7f']
# ---
# Файлов нет
# ---
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/50
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/03
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/0e
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/d1
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/d8
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/f3
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/fb
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/pack
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/1a
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/10
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/75
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/9f
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/6b
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/info
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/54
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/97
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/d4
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/c3
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/cc
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/e6
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/e8
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/ff
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/cb
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/77
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/4f
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/7f
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/50
# ---
# Папок нет
# ---
# Список файлов ['54b23c4f82bab9f439463fad99af02fad99abe']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/50/54b23c4f82bab9f439463fad99af02fad99abe
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/03
# ---
# Папок нет
# ---
# Список файлов ['799f6cd6a7c652c67fbc61c7ce8df9204b8fb3']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/03/799f6cd6a7c652c67fbc61c7ce8df9204b8fb3
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/0e
# ---
# Папок нет
# ---
# Список файлов ['f7c301e3f162c05d4352b5a7f2a14654ddd4a3', '3e47bfece7e3966fddfb842dc5664f147f07b5']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/0e/f7c301e3f162c05d4352b5a7f2a14654ddd4a3
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/0e/3e47bfece7e3966fddfb842dc5664f147f07b5
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/d1
# ---
# Папок нет
# ---
# Список файлов ['8e343ab98141da352c7a38987a33011102aa3d']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/d1/8e343ab98141da352c7a38987a33011102aa3d
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/d8
# ---
# Папок нет
# ---
# Список файлов ['c6523b2905e8a4731d60c2244325333c7e0925']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/d8/c6523b2905e8a4731d60c2244325333c7e0925
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/f3
# ---
# Папок нет
# ---
# Список файлов ['cdfee5157d384eb526208bd403270f72315868']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/f3/cdfee5157d384eb526208bd403270f72315868
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/fb
# ---
# Папок нет
# ---
# Список файлов ['3ebed2075dfce669d8005835758ba0cf9b50ca']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/fb/3ebed2075dfce669d8005835758ba0cf9b50ca
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/pack
# ---
# Папок нет
# ---
# Список файлов ['pack-10394a7ca92fb00aa7332c6d7f4fc390cc1e4760.pack', 'pack-10394a7ca92fb00aa7332c6d7f4fc390cc1e4760.rev', 'pack-10394a7ca92fb00aa7332c6d7f4fc390cc1e4760.idx']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/pack/pack-10394a7ca92fb00aa7332c6d7f4fc390cc1e4760.pack
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/pack/pack-10394a7ca92fb00aa7332c6d7f4fc390cc1e4760.rev
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/pack/pack-10394a7ca92fb00aa7332c6d7f4fc390cc1e4760.idx
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/1a
# ---
# Папок нет
# ---
# Список файлов ['cd781d383309fa74600208dda8f26d7a267dad']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/1a/cd781d383309fa74600208dda8f26d7a267dad
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/10
# ---
# Папок нет
# ---
# Список файлов ['aa35f9eb97852bd9d8c661ae32b3324b950728']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/10/aa35f9eb97852bd9d8c661ae32b3324b950728
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/75
# ---
# Папок нет
# ---
# Список файлов ['151e854d7ef0864a475c03f76440c59300b1c7']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/75/151e854d7ef0864a475c03f76440c59300b1c7
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/9f
# ---
# Папок нет
# ---
# Список файлов ['e8765e251ffb618b251f20d90b37a4f7ba6c09']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/9f/e8765e251ffb618b251f20d90b37a4f7ba6c09
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/6b
# ---
# Папок нет
# ---
# Список файлов ['aa86b685b75526db9f764846275edea97d9d29']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/6b/aa86b685b75526db9f764846275edea97d9d29
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/info
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/54
# ---
# Папок нет
# ---
# Список файлов ['f657bb0972cd4d4bf69ad88524d3055b9da03b']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/54/f657bb0972cd4d4bf69ad88524d3055b9da03b
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/97
# ---
# Папок нет
# ---
# Список файлов ['75cf0545f65aeb20cba6932fd975de2874b285']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/97/75cf0545f65aeb20cba6932fd975de2874b285
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/d4
# ---
# Папок нет
# ---
# Список файлов ['5c9825b9f8151472c145d32c60c1191b7f3ed3']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/d4/5c9825b9f8151472c145d32c60c1191b7f3ed3
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/c3
# ---
# Папок нет
# ---
# Список файлов ['90a52a8361ea0e6a1ba3b46b411bb96fd6d8c2']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/c3/90a52a8361ea0e6a1ba3b46b411bb96fd6d8c2
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/cc
# ---
# Папок нет
# ---
# Список файлов ['2b7823653662a32e3a382ff63d93332504bd4e']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/cc/2b7823653662a32e3a382ff63d93332504bd4e
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/e6
# ---
# Папок нет
# ---
# Список файлов ['9de29bb2d1d6434b8b29ae775ad8c2e48c5391']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/e6/9de29bb2d1d6434b8b29ae775ad8c2e48c5391
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/e8
# ---
# Папок нет
# ---
# Список файлов ['6b1aca176e2f160935d384e391dbdafbc5f201']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/e8/6b1aca176e2f160935d384e391dbdafbc5f201
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/ff
# ---
# Папок нет
# ---
# Список файлов ['d919bcfb1b1138710a3c20396ab26821b6ffa4']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/ff/d919bcfb1b1138710a3c20396ab26821b6ffa4
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/cb
# ---
# Папок нет
# ---
# Список файлов ['ecc5ee9256bb7a46fbd36f2770436625a443ea']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/cb/ecc5ee9256bb7a46fbd36f2770436625a443ea
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/77
# ---
# Папок нет
# ---
# Список файлов ['db9f7ee7dc008332a3f02f5a7fae506d6dc089']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/77/db9f7ee7dc008332a3f02f5a7fae506d6dc089
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/4f
# ---
# Папок нет
# ---
# Список файлов ['204c3bc12cfd18231ddcd2240d51b10198d998']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/4f/204c3bc12cfd18231ddcd2240d51b10198d998
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/7f
# ---
# Папок нет
# ---
# Список файлов ['021e6d40adc61e3b01b610ba0a5e373eac4cbf']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/objects/7f/021e6d40adc61e3b01b610ba0a5e373eac4cbf
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/info
# ---
# Папок нет
# ---
# Список файлов ['exclude']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/info/exclude
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/logs
# ---
# Список папок ['refs']
# ---
# Список файлов ['HEAD']
# ---
# Все пути:
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/logs/HEAD
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/logs/refs
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/logs/refs
# ---
# Список папок ['heads', 'remotes']
# ---
# Файлов нет
# ---
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/logs/refs/heads
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/logs/refs/remotes
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/logs/refs/heads
# ---
# Папок нет
# ---
# Список файлов ['py13', 'master']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/logs/refs/heads/py13
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/logs/refs/heads/master
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/logs/refs/remotes
# ---
# Список папок ['origin']
# ---
# Файлов нет
# ---
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/logs/refs/remotes/origin
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/logs/refs/remotes/origin
# ---
# Папок нет
# ---
# Список файлов ['py13', 'HEAD']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/logs/refs/remotes/origin/py13
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/logs/refs/remotes/origin/HEAD
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/hooks
# ---
# Папок нет
# ---
# Список файлов ['commit-msg.sample', 'pre-rebase.sample', 'sendemail-validate.sample', 'pre-commit.sample', 'applypatch-msg.sample', 'fsmonitor-watchman.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'post-update.sample', 'pre-merge-commit.sample', 'pre-applypatch.sample', 'pre-push.sample', 'update.sample', 'push-to-checkout.sample']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/hooks/commit-msg.sample
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/hooks/pre-rebase.sample
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/hooks/sendemail-validate.sample
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/hooks/pre-commit.sample
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/hooks/applypatch-msg.sample
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/hooks/fsmonitor-watchman.sample
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/hooks/pre-receive.sample
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/hooks/prepare-commit-msg.sample
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/hooks/post-update.sample
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/hooks/pre-merge-commit.sample
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/hooks/pre-applypatch.sample
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/hooks/pre-push.sample
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/hooks/update.sample
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/hooks/push-to-checkout.sample
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/refs
# ---
# Список папок ['heads', 'tags', 'remotes']
# ---
# Файлов нет
# ---
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/refs/heads
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/refs/tags
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/refs/remotes
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/refs/heads
# ---
# Папок нет
# ---
# Список файлов ['py13', 'master']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/refs/heads/py13
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/refs/heads/master
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/refs/tags
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/refs/remotes
# ---
# Список папок ['origin']
# ---
# Файлов нет
# ---
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.git/refs/remotes/origin
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.git/refs/remotes/origin
# ---
# Папок нет
# ---
# Список файлов ['py13', 'HEAD']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/refs/remotes/origin/py13
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.git/refs/remotes/origin/HEAD
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/PY_13_visualisation
# ---
# Список папок ['plotly', 'data']
# ---
# Список файлов ['visualisation.py', 'visualisation_practice.ipynb', 'covid.py', 'visualisation.ipynb']
# ---
# Все пути:
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_13_visualisation/visualisation.py
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_13_visualisation/visualisation_practice.ipynb
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_13_visualisation/covid.py
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_13_visualisation/visualisation.ipynb
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/PY_13_visualisation/plotly
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/PY_13_visualisation/data
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/PY_13_visualisation/plotly
# ---
# Папок нет
# ---
# Список файлов ['scatter_3d.html']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_13_visualisation/plotly/scatter_3d.html
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/PY_13_visualisation/data
# ---
# Папок нет
# ---
# Список файлов ['covid_data.csv', 'countries.csv', 'country_vaccinations.csv', 'Video_Games_Sales_as_at_22_Dec_2016.csv', 'churn.csv']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_13_visualisation/data/covid_data.csv
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_13_visualisation/data/countries.csv
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_13_visualisation/data/country_vaccinations.csv
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_13_visualisation/data/Video_Games_Sales_as_at_22_Dec_2016.csv
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/PY_13_visualisation/data/churn.csv
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.idea
# ---
# Список папок ['inspectionProfiles', 'dictionaries']
# ---
# Список файлов ['vcs.xml', '.gitignore', 'workspace.xml', 'modules.xml', 'misc.xml', 'python-practice.iml']
# ---
# Все пути:
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.idea/vcs.xml
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.idea/.gitignore
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.idea/workspace.xml
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.idea/modules.xml
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.idea/misc.xml
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.idea/python-practice.iml
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.idea/inspectionProfiles
# Папка  /Users/gregnaumkin/PycharmProjects/python-practice/.idea/dictionaries
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.idea/inspectionProfiles
# ---
# Папок нет
# ---
# Список файлов ['profiles_settings.xml']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.idea/inspectionProfiles/profiles_settings.xml
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/python-practice/.idea/dictionaries
# ---
# Папок нет
# ---
# Список файлов ['gregnaumkin.xml']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/python-practice/.idea/dictionaries/gregnaumkin.xml
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project
# ---
# Список папок ['.git', '.idea']
# ---
# Список файлов ['requirements.txt', 'game.py', 'README.md', '.gitignore']
# ---
# Все пути:
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/requirements.txt
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/game.py
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/README.md
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.gitignore
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.idea
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git
# ---
# Список папок ['objects', 'info', 'logs', 'hooks', 'refs']
# ---
# Список файлов ['config', 'HEAD', 'description', 'index', 'packed-refs', 'COMMIT_EDITMSG']
# ---
# Все пути:
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/config
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/HEAD
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/description
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/index
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/packed-refs
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/COMMIT_EDITMSG
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/info
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/logs
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/hooks
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/refs
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects
# ---
# Список папок ['92', '9e', 'ad', 'ae', 'e2', 'ca', '27', 'pack', '00', '09', 'info', '91', 'dd', 'd5', 'aa', 'e6', 'e9', '41', '15', '82', '8b']
# ---
# Файлов нет
# ---
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/92
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/9e
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/ad
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/ae
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/e2
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/ca
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/27
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/pack
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/00
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/09
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/info
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/91
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/dd
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/d5
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/aa
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/e6
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/e9
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/41
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/15
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/82
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/8b
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/92
# ---
# Папок нет
# ---
# Список файлов ['2c8ebda55365f0647158cf5beaec15ee15c239']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/92/2c8ebda55365f0647158cf5beaec15ee15c239
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/9e
# ---
# Папок нет
# ---
# Список файлов ['95262aebea1e71083462f92e6bc5e4fe029c58']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/9e/95262aebea1e71083462f92e6bc5e4fe029c58
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/ad
# ---
# Папок нет
# ---
# Список файлов ['6a18a612a0d50ab9afa9997edf5517ec1628f1']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/ad/6a18a612a0d50ab9afa9997edf5517ec1628f1
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/ae
# ---
# Папок нет
# ---
# Список файлов ['5a83164d2abd0e5fe8af4a453e595cba7365dd']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/ae/5a83164d2abd0e5fe8af4a453e595cba7365dd
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/e2
# ---
# Папок нет
# ---
# Список файлов ['3c7b276f936536558846260396f188f5821256']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/e2/3c7b276f936536558846260396f188f5821256
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/ca
# ---
# Папок нет
# ---
# Список файлов ['69f7fe0fa8b3e1c98a6cfb4abc821e9e6c460d']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/ca/69f7fe0fa8b3e1c98a6cfb4abc821e9e6c460d
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/27
# ---
# Папок нет
# ---
# Список файлов ['ca8eb6f78e2cbfa6c544b755b413691db50fb4']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/27/ca8eb6f78e2cbfa6c544b755b413691db50fb4
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/pack
# ---
# Папок нет
# ---
# Список файлов ['pack-010d9a21e0134544ae3acd636153bb4e321b0bcd.rev', 'pack-010d9a21e0134544ae3acd636153bb4e321b0bcd.idx', 'pack-010d9a21e0134544ae3acd636153bb4e321b0bcd.pack']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/pack/pack-010d9a21e0134544ae3acd636153bb4e321b0bcd.rev
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/pack/pack-010d9a21e0134544ae3acd636153bb4e321b0bcd.idx
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/pack/pack-010d9a21e0134544ae3acd636153bb4e321b0bcd.pack
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/00
# ---
# Папок нет
# ---
# Список файлов ['868f58ad0336af395e2807cdb330ce8896475c']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/00/868f58ad0336af395e2807cdb330ce8896475c
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/09
# ---
# Папок нет
# ---
# Список файлов ['1aaa6bc9b99405d04e59ce098740c1f55ddcac']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/09/1aaa6bc9b99405d04e59ce098740c1f55ddcac
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/info
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/91
# ---
# Папок нет
# ---
# Список файлов ['97e745e9794654b7b3dce8610ee4d828e26634']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/91/97e745e9794654b7b3dce8610ee4d828e26634
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/dd
# ---
# Папок нет
# ---
# Список файлов ['9a364545bbf7798c1d277894a04ca55e935220']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/dd/9a364545bbf7798c1d277894a04ca55e935220
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/d5
# ---
# Папок нет
# ---
# Список файлов ['dda943921414017f1b0d47d5166436abf60e2b']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/d5/dda943921414017f1b0d47d5166436abf60e2b
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/aa
# ---
# Папок нет
# ---
# Список файлов ['b7939281df2fa0e39c985979b773418837f800']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/aa/b7939281df2fa0e39c985979b773418837f800
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/e6
# ---
# Папок нет
# ---
# Список файлов ['9de29bb2d1d6434b8b29ae775ad8c2e48c5391']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/e6/9de29bb2d1d6434b8b29ae775ad8c2e48c5391
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/e9
# ---
# Папок нет
# ---
# Список файлов ['723db3d7eca6c5d24729f1ee5b98eae235390d']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/e9/723db3d7eca6c5d24729f1ee5b98eae235390d
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/41
# ---
# Папок нет
# ---
# Список файлов ['e27436f4c5f5e8d2e5c70ef7437a08ee050d27']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/41/e27436f4c5f5e8d2e5c70ef7437a08ee050d27
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/15
# ---
# Папок нет
# ---
# Список файлов ['5ebae52765a240cd02aaa7c28b147ee8a6698f']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/15/5ebae52765a240cd02aaa7c28b147ee8a6698f
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/82
# ---
# Папок нет
# ---
# Список файлов ['e5d98dbaa42342dddf92e764b6e89c557743f8']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/82/e5d98dbaa42342dddf92e764b6e89c557743f8
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/8b
# ---
# Папок нет
# ---
# Список файлов ['7219ba779b7ca96a7264d468f79f6ffbef0345']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/objects/8b/7219ba779b7ca96a7264d468f79f6ffbef0345
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/info
# ---
# Папок нет
# ---
# Список файлов ['exclude']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/info/exclude
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/logs
# ---
# Список папок ['refs']
# ---
# Список файлов ['HEAD']
# ---
# Все пути:
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/logs/HEAD
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/logs/refs
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/logs/refs
# ---
# Список папок ['heads', 'remotes']
# ---
# Файлов нет
# ---
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/logs/refs/heads
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/logs/refs/remotes
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/logs/refs/heads
# ---
# Папок нет
# ---
# Список файлов ['master', 'feature']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/logs/refs/heads/master
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/logs/refs/heads/feature
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/logs/refs/remotes
# ---
# Список папок ['origin']
# ---
# Файлов нет
# ---
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/logs/refs/remotes/origin
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/logs/refs/remotes/origin
# ---
# Папок нет
# ---
# Список файлов ['HEAD', 'feature']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/logs/refs/remotes/origin/HEAD
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/logs/refs/remotes/origin/feature
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/hooks
# ---
# Папок нет
# ---
# Список файлов ['commit-msg.sample', 'pre-rebase.sample', 'sendemail-validate.sample', 'pre-commit.sample', 'applypatch-msg.sample', 'fsmonitor-watchman.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'post-update.sample', 'pre-merge-commit.sample', 'pre-applypatch.sample', 'pre-push.sample', 'update.sample', 'push-to-checkout.sample']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/hooks/commit-msg.sample
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/hooks/pre-rebase.sample
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/hooks/sendemail-validate.sample
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/hooks/pre-commit.sample
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/hooks/applypatch-msg.sample
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/hooks/fsmonitor-watchman.sample
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/hooks/pre-receive.sample
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/hooks/prepare-commit-msg.sample
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/hooks/post-update.sample
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/hooks/pre-merge-commit.sample
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/hooks/pre-applypatch.sample
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/hooks/pre-push.sample
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/hooks/update.sample
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/hooks/push-to-checkout.sample
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/refs
# ---
# Список папок ['heads', 'tags', 'remotes']
# ---
# Файлов нет
# ---
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/refs/heads
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/refs/tags
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/refs/remotes
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/refs/heads
# ---
# Папок нет
# ---
# Список файлов ['master', 'feature']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/refs/heads/master
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/refs/heads/feature
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/refs/tags
# ---
# Папок нет
# ---
# Файлов нет
# ---
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/refs/remotes
# ---
# Список папок ['origin']
# ---
# Файлов нет
# ---
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/refs/remotes/origin
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/refs/remotes/origin
# ---
# Папок нет
# ---
# Список файлов ['HEAD', 'feature']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/refs/remotes/origin/HEAD
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.git/refs/remotes/origin/feature
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.idea
# ---
# Список папок ['inspectionProfiles']
# ---
# Список файлов ['sf-home-work-project.iml', 'vcs.xml', '.gitignore', 'workspace.xml', 'modules.xml', 'misc.xml']
# ---
# Все пути:
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.idea/sf-home-work-project.iml
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.idea/vcs.xml
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.idea/.gitignore
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.idea/workspace.xml
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.idea/modules.xml
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.idea/misc.xml
# Папка  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.idea/inspectionProfiles
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.idea/inspectionProfiles
# ---
# Папок нет
# ---
# Список файлов ['profiles_settings.xml']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/sf-home-work-project/.idea/inspectionProfiles/profiles_settings.xml
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/practice
# ---
# Список папок ['.venv', '.idea']
# ---
# Список файлов ['PYTHON-4. Практика.ipynb']
# ---
# Все пути:
# Файл  /Users/gregnaumkin/PycharmProjects/practice/PYTHON-4. Практика.ipynb
# Папка  /Users/gregnaumkin/PycharmProjects/practice/.venv
# Папка  /Users/gregnaumkin/PycharmProjects/practice/.idea
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/practice/.venv
# ---
# Список папок ['bin', 'lib']
# ---
# Список файлов ['pyvenv.cfg', '.gitignore']
# ---
# Все пути:
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/pyvenv.cfg
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/.gitignore
# Папка  /Users/gregnaumkin/PycharmProjects/practice/.venv/bin
# Папка  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/practice/.venv/bin
# ---
# Папок нет
# ---
# Список файлов ['wheel3.11', 'wheel3', 'activate.ps1', 'python3', 'python', 'pip3', 'pip-3.11', 'activate.fish', 'wheel', 'python3.11', 'wheel-3.11', 'activate_this.py', 'pip', 'pip3.11', 'activate', 'activate.nu', 'activate.csh']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/bin/wheel3.11
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/bin/wheel3
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/bin/activate.ps1
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/bin/python3
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/bin/python
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/bin/pip3
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/bin/pip-3.11
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/bin/activate.fish
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/bin/wheel
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/bin/python3.11
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/bin/wheel-3.11
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/bin/activate_this.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/bin/pip
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/bin/pip3.11
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/bin/activate
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/bin/activate.nu
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/bin/activate.csh
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/practice/.venv/lib
# ---
# Список папок ['python3.11']
# ---
# Файлов нет
# ---
# Папка  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11
# ---
# Список папок ['site-packages']
# ---
# Файлов нет
# ---
# Папка  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages
# ---
# Список папок ['wheel', '__pycache__', 'pip', 'pip-23.2.1.dist-info', 'setuptools-68.2.0.dist-info', 'setuptools', 'pkg_resources', '_distutils_hack', 'wheel-0.41.2.dist-info']
# ---
# Список файлов ['setuptools-68.2.0.virtualenv', 'pip-23.2.1.virtualenv', '_virtualenv.py', 'distutils-precedence.pth', '_virtualenv.pth', 'wheel-0.41.2.virtualenv']
# ---
# Все пути:
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools-68.2.0.virtualenv
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pip-23.2.1.virtualenv
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/_virtualenv.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/distutils-precedence.pth
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/_virtualenv.pth
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/wheel-0.41.2.virtualenv
# Папка  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/wheel
# Папка  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/__pycache__
# Папка  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pip
# Папка  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pip-23.2.1.dist-info
# Папка  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools-68.2.0.dist-info
# Папка  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools
# Папка  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources
# Папка  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/_distutils_hack
# Папка  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/wheel-0.41.2.dist-info
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/wheel
# ---
# Список папок ['cli', 'vendored']
# ---
# Список файлов ['metadata.py', 'macosx_libfile.py', 'util.py', '_setuptools_logging.py', '__init__.py', 'bdist_wheel.py', 'wheelfile.py', '__main__.py']
# ...
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/sysconfig.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/_macos_compat.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/py39compat.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/py38compat.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/dist.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/_log.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/bcppcompiler.py
# Папка  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/command
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/command
# ---
# Папок нет
# ---
# Список файлов ['build.py', 'py37compat.py', 'build_ext.py', 'config.py', 'clean.py', 'check.py', 'install_scripts.py', 'upload.py', 'register.py', '_framework_compat.py', 'install_headers.py', 'install_lib.py', 'build_py.py', 'bdist_dumb.py', '__init__.py', 'sdist.py', 'bdist.py', 'build_scripts.py', 'bdist_rpm.py', 'build_clib.py', 'install.py', 'install_egg_info.py', 'install_data.py']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/command/build.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/command/py37compat.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/command/build_ext.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/command/config.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/command/clean.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/command/check.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/command/install_scripts.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/command/upload.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/command/register.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/command/_framework_compat.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/command/install_headers.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/command/install_lib.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/command/build_py.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/command/bdist_dumb.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/command/__init__.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/command/sdist.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/command/bdist.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/command/build_scripts.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/command/bdist_rpm.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/command/build_clib.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/command/install.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/command/install_egg_info.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/setuptools/_distutils/command/install_data.py
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources
# ---
# Список папок ['_vendor', 'extern']
# ---
# Список файлов ['__init__.py']
# ---
# Все пути:
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/__init__.py
# Папка  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor
# Папка  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/extern
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor
# ---
# Список папок ['packaging', 'jaraco', 'more_itertools', 'importlib_resources', 'platformdirs']
# ---
# Список файлов ['__init__.py', 'zipp.py', 'typing_extensions.py']
# ---
# Все пути:
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/__init__.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/zipp.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/typing_extensions.py
# Папка  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/packaging
# Папка  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/jaraco
# Папка  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/more_itertools
# Папка  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/importlib_resources
# Папка  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/platformdirs
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/packaging
# ---
# Папок нет
# ---
# Список файлов ['tags.py', '_musllinux.py', 'metadata.py', 'version.py', '__init__.py', '_parser.py', 'utils.py', 'requirements.py', '_structures.py', 'markers.py', '_manylinux.py', '_tokenizer.py', 'specifiers.py', '_elffile.py']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/packaging/tags.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/packaging/_musllinux.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/packaging/metadata.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/packaging/version.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/packaging/__init__.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/packaging/_parser.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/packaging/utils.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/packaging/requirements.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/packaging/_structures.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/packaging/markers.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/packaging/_manylinux.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/packaging/_tokenizer.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/packaging/specifiers.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/packaging/_elffile.py
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/jaraco
# ---
# Список папок ['text']
# ---
# Список файлов ['functools.py', '__init__.py', 'context.py']
# ---
# Все пути:
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/jaraco/functools.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/jaraco/__init__.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/jaraco/context.py
# Папка  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/jaraco/text
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/jaraco/text
# ---
# Папок нет
# ---
# Список файлов ['__init__.py']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/jaraco/text/__init__.py
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/more_itertools
# ---
# Папок нет
# ---
# Список файлов ['__init__.py', 'more.py', 'recipes.py']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/more_itertools/__init__.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/more_itertools/more.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/more_itertools/recipes.py
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/importlib_resources
# ---
# Папок нет
# ---
# Список файлов ['readers.py', '_common.py', '__init__.py', '_itertools.py', '_adapters.py', '_compat.py', '_legacy.py', 'simple.py', 'abc.py']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/importlib_resources/readers.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/importlib_resources/_common.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/importlib_resources/__init__.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/importlib_resources/_itertools.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/importlib_resources/_adapters.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/importlib_resources/_compat.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/importlib_resources/_legacy.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/importlib_resources/simple.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/importlib_resources/abc.py
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/platformdirs
# ---
# Папок нет
# ---
# Список файлов ['macos.py', 'unix.py', 'version.py', '__init__.py', 'api.py', 'android.py', 'windows.py', '__main__.py']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/platformdirs/macos.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/platformdirs/unix.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/platformdirs/version.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/platformdirs/__init__.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/platformdirs/api.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/platformdirs/android.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/platformdirs/windows.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/_vendor/platformdirs/__main__.py
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/extern
# ---
# Папок нет
# ---
# Список файлов ['__init__.py']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/pkg_resources/extern/__init__.py
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/_distutils_hack
# ---
# Список папок ['__pycache__']
# ---
# Список файлов ['__init__.py', 'override.py']
# ---
# Все пути:
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/_distutils_hack/__init__.py
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/_distutils_hack/override.py
# Папка  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/_distutils_hack/__pycache__
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/_distutils_hack/__pycache__
# ---
# Папок нет
# ---
# Список файлов ['__init__.cpython-311.pyc']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/_distutils_hack/__pycache__/__init__.cpython-311.pyc
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/wheel-0.41.2.dist-info
# ---
# Папок нет
# ---
# Список файлов ['RECORD', 'WHEEL', 'entry_points.txt', 'LICENSE.txt', 'INSTALLER', 'METADATA']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/wheel-0.41.2.dist-info/RECORD
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/wheel-0.41.2.dist-info/WHEEL
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/wheel-0.41.2.dist-info/entry_points.txt
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/wheel-0.41.2.dist-info/LICENSE.txt
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/wheel-0.41.2.dist-info/INSTALLER
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.venv/lib/python3.11/site-packages/wheel-0.41.2.dist-info/METADATA
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/practice/.idea
# ---
# Список папок ['inspectionProfiles']
# ---
# Список файлов ['practice.iml', '.gitignore', 'workspace.xml', 'modules.xml']
# ---
# Все пути:
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.idea/practice.iml
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.idea/.gitignore
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.idea/workspace.xml
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.idea/modules.xml
# Папка  /Users/gregnaumkin/PycharmProjects/practice/.idea/inspectionProfiles
# ===
# Текущая директория /Users/gregnaumkin/PycharmProjects/practice/.idea/inspectionProfiles
# ---
# Папок нет
# ---
# Список файлов ['profiles_settings.xml']
# ---
# Файл  /Users/gregnaumkin/PycharmProjects/practice/.idea/inspectionProfiles/profiles_settings.xml
# ===

# %%
os.chdir("/Users/gregnaumkin/PycharmProjects/python-practice/PY_15_OOP")
current_path = os.getcwd()
print(current_path)
# Out:
# /Users/gregnaumkin/PycharmProjects/python-practice/PY_15_OOP

# %%
f = open('test.txt', 'w', encoding='utf8')

# Запишем в файл строку
f.write("This is a test string\n")
f.write("This is a new string\n")

# обязательно нужно закрыть файл иначе он будет заблокирован ОС
f.close()

# %%
f = open('test.txt', 'r', encoding='utf8')
print(f.read(10))
start_path = os.getcwd()
print(start_path)
# Out:
# This is a
# /Users/gregnaumkin/PycharmProjects/python-practice/PY_15_OOP

# %%
# считали остаток файла
print(f.read())
f.close()
# Out:
# test string
# This is a new string

# %%
f = open('test.txt', 'a', encoding='utf8') # открываем файл на дозапись

sequence = ["other string\n", "123\n", "test test\n"]
f.writelines(sequence) # берет строки из sequence и записывает в файл (без переносов)

f.close()

# %%
f = open('test.txt', 'r', encoding='utf8')

print(f.readlines()) # считывает все строки в список и возвращает список

f.close()
# Out:
# ['This is a test string\n', 'This is a new string\n', 'other string\n', '123\n', 'test test\n']

# %%
f = open('test.txt', 'r', encoding='utf8')

print(f.readline()) # This is a test string
print(f.read(4)) # This
print(f.readline()) # is a new string

f.close()
# Out:
# This is a test string
#
# This
#  is a new string

# %%
f = open('test.txt')  # можно перечислять строки в файле
for line in f:
    print(line, end='')

# This is a test string
# This is a new string
# other string
# 123
# test test

f.close()
# Out:
# This is a test string
# This is a new string
# other string
# 123
# test test

# %%
with open("test.txt", 'rb') as f:
    a = f.read(10)
    b = f.read(23)

# %%
with open("input.txt", "r") as input_file:
    with open("output.txt", "w") as output_file:
        for line in input_file:
            output_file.write(line)

# %%
filename = 'numbers.txt'
output = 'output.txt'

with open(filename) as f:
    min_ = max_ = float(f.readline())  # считали первое число
    for line in f:
        num =  float(line)
        if num > max_:
            max_ = num
        elif num < min_:
            min_ = num

    sum_ = min_ + max_

with open(output, 'w') as f:
    f.write(str(sum_))
    f.write('\n')
